# %%
from numba import cuda
print(cuda.is_available())
# Out:
# True

# %%
# %cd /content
# !rm -rf Mini_torch
# Out:
# /content

# %%
# !ls /content
# Out:
# sample_data

# %%
# !unzip -q 2.zip
# %cd /content/Mini_torch
# Out:
# /content/Mini_torch

# %%
# !ls
# Out:
# images		    project		    requirements.txt  tests
# minitorch	    README.md		    setup.cfg
# minitorch.egg-info  requirements.extra.txt  setup.py

# %%
# !pip install colorama hypothesis pytest numpy numba typing_extensions
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.1/532.1 kB 14.9 MB/s eta 0:00:00
# ...

# %%
# !grep -n "Need to implement for Task 3.3" minitorch/cuda_ops.py

# %%
# !python -m pytest -m task3_3 -x -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# hypothesis profile 'default'
# rootdir: /content/Mini_torch
# configfile: setup.cfg
# plugins: hypothesis-6.152.4, typeguard-4.5.1, anyio-4.13.0, langsmith-0.7.34
# collected 294 items / 237 deselected / 57 selected
#
# tests/test_tensor_general.py::test_create[cuda] PASSED                   [  1%]
# tests/test_tensor_general.py::test_one_args[cuda-fn0] PASSED             [  3%]
# tests/test_tensor_general.py::test_one_args[cuda-fn1] PASSED             [  5%]
# tests/test_tensor_general.py::test_one_args[cuda-fn2] PASSED             [  7%]
# tests/test_tensor_general.py::test_one_args[cuda-fn3] PASSED             [  8%]
# tests/test_tensor_general.py::test_one_args[cuda-fn4] PASSED             [ 10%]
# tests/test_tensor_general.py::test_one_args[cuda-fn5] PASSED             [ 12%]
# ...

# %%
# !unzip -q 3.zip
# %cd /content/Mini_torch
# Out:
# /content/Mini_torch

# %%
# !rm -rf Mini_torch
# %cd /content/Mini_torch
# !ls /content
# !ls
# Out:
# /content/Mini_torch
# 3.zip  Mini_torch  sample_data
# images		    README.md		    setup.py
# minitorch	    requirements.extra.txt  tests
# minitorch.egg-info  requirements.txt	    Как_запускать_тeсты_3_3.ipynb
# project		    setup.cfg

# %%
# !grep -n "Need to implement for Task 3.3" minitorch/cuda_ops.py

# %%
# !python -m pytest -m task3_3 -x -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# hypothesis profile 'default'
# rootdir: /content/Mini_torch
# configfile: setup.cfg
# plugins: hypothesis-6.152.4, typeguard-4.5.1, anyio-4.13.0, langsmith-0.7.34
# collected 294 items / 237 deselected / 57 selected
#
# tests/test_tensor_general.py::test_create[cuda] PASSED                   [  1%]
# tests/test_tensor_general.py::test_one_args[cuda-fn0] PASSED             [  3%]
# tests/test_tensor_general.py::test_one_args[cuda-fn1] PASSED             [  5%]
# tests/test_tensor_general.py::test_one_args[cuda-fn2] PASSED             [  7%]
# tests/test_tensor_general.py::test_one_args[cuda-fn3] PASSED             [  8%]
# tests/test_tensor_general.py::test_one_args[cuda-fn4] PASSED             [ 10%]
# tests/test_tensor_general.py::test_one_args[cuda-fn5] PASSED             [ 12%]
# ...

# %%
# !python -m pytest -m task3_4 -x -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# hypothesis profile 'default'
# rootdir: /content/Mini_torch
# configfile: setup.cfg
# plugins: hypothesis-6.152.4, typeguard-4.5.1, anyio-4.13.0, langsmith-0.7.34
# collected 294 items / 287 deselected / 7 selected
#
# tests/test_tensor_general.py::test_mul_practice1 PASSED                  [ 14%]
# tests/test_tensor_general.py::test_mul_practice2 PASSED                  [ 28%]
# tests/test_tensor_general.py::test_mul_practice3 PASSED                  [ 42%]
# tests/test_tensor_general.py::test_mul_practice4 PASSED                  [ 57%]
# tests/test_tensor_general.py::test_mul_practice5 PASSED                  [ 71%]
# tests/test_tensor_general.py::test_mul_practice6 PASSED                  [ 85%]
# tests/test_tensor_general.py::test_bmm[cuda] PASSED                      [100%]
#
# ...

# %%
# !unzip -q 4.zip
# %cd /content/Mini_torch

# !rm -rf Mini_torch
# %cd /content/Mini_torch
# !ls /content
# !ls
# Out:
# unzip:  cannot find or open 4.zip, 4.zip.zip or 4.zip.ZIP.
# /content/Mini_torch
# /content/Mini_torch
# 4.zip  Mini_torch  sample_data
# images		    README.md		    setup.py
# minitorch	    requirements.extra.txt  tests
# minitorch.egg-info  requirements.txt	    Как_запускать_тeсты_3_3.ipynb
# project		    setup.cfg

# %%
# %cd /content/Mini_torch
# !pip install -e .
# !python project/run_fast_tensor.py --BACKEND gpu --HIDDEN 100 --DATASET split --RATE 0.05
# Out:
# /content/Mini_torch
# Obtaining file:///content/Mini_torch
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: minitorch
#     Found existing installation: minitorch 0.4
#     Uninstalling minitorch-0.4:
#       Successfully uninstalled minitorch-0.4
#   Running setup.py develop for minitorch
# ...
# (2, -1) (3, 4) (4, 6) (5, 9) ||| (2, -1) (3, 4) (4, 6) (5, 9)
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 1 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/cudadrv/devicearray.py:934: NumbaPerformanceWarning: Host array used in CUDA kernel will incur copy overhead to/from device.
#   warn(NumbaPerformanceWarning(msg))
# ...

# %%
# %cd /content/Mini_torch
# !python project/run_fast_tensor.py --BACKEND gpu --HIDDEN 100 --DATASET xor --RATE 0.05
# Out:
# /content/Mini_torch
# (2, -1) (3, 4) (4, 6) (5, 9) ||| (2, -1) (3, 4) (4, 6) (5, 9)
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 1 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/cudadrv/devicearray.py:934: NumbaPerformanceWarning: Host array used in CUDA kernel will incur copy overhead to/from device.
#   warn(NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 7 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/cudadrv/devicearray.py:934: NumbaPerformanceWarning: Host array used in CUDA kernel will incur copy overhead to/from device.
# ...

# %%
# %cd /content/Mini_torch
# !python project/run_fast_tensor.py --BACKEND gpu --HIDDEN 100 --DATASET simple --RATE 0.05
# Out:
# /content/Mini_torch
# (2, -1) (3, 4) (4, 6) (5, 9) ||| (2, -1) (3, 4) (4, 6) (5, 9)
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 1 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/cudadrv/devicearray.py:934: NumbaPerformanceWarning: Host array used in CUDA kernel will incur copy overhead to/from device.
#   warn(NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 7 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/cudadrv/devicearray.py:934: NumbaPerformanceWarning: Host array used in CUDA kernel will incur copy overhead to/from device.
# ...
